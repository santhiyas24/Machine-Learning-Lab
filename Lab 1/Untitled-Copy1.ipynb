# %%
print("hello world")
# Out:
# hello world

# %%
num1 = 15
num2 = 15.15
ch = 'a'
str = 'string'
print (num1)
print (num2)
print (str)
print(ch)
# Out:
# 15
# 15.15
# string
# a

# %%
a = b = 20 
x, y, z = 10, 15.2, "string"
print (x)
print (y)
print (z)
# Out:
# 10
# 15.2
# string

# %%
x = 3.14j
print(x, x.real, x.imag)
# Out:
# 3.14j 0.0 3.14

# %%
a = True 
x = True + 10
y = False + 10
print("x:", x)
print("y:", y)
# Out:
# x: 11
# y: 10

# %%
x = None
print(x)
# Out:
# None

# %%
List_Items = ['I1', 'I2', 'I3']

print("Tuple literals are enclosed within brackets.")
Tuple_Items = ("I1", "I2", "I3")

print("Dictionary literals are enclosed within curly braces.")
gender = {'m': 'male', 'f': 'female'}

print("Set literals are enclosed within curly braces.")
animals = {"cat", "dog", "rabbit"}

print(List_Items)
print(Tuple_Items)
print(gender)
print(animals)
# Out:
# Tuple literals are enclosed within brackets.
# Dictionary literals are enclosed within curly braces.
# Set literals are enclosed within curly braces.
# ['I1', 'I2', 'I3']
# ('I1', 'I2', 'I3')
# {'m': 'male', 'f': 'female'}
# {'cat', 'dog', 'rabbit'}

# %%
x = 40
y = 20
z = 50
if x>y and x>z:
     print("x is greater")
elif y>x and y>z:
    print("y is greater")
else:
    print("z is greater")
# Out:
# z is greater

# %%
x = 10
while x>5:
 print(x)
 x = x-1
 print("while loop executed")
# Out:
# 10
# while loop executed
# 9
# while loop executed
# 8
# while loop executed
# 7
# while loop executed
# 6
# while loop executed

# %%
x = 10
while x>5:
    print(x)
    x = x-1
    print("while loop executed")
else:
   print("Inside else")
# Out:
# 10
# while loop executed
# 9
# while loop executed
# 8
# while loop executed
# 7
# while loop executed
# 6
# while loop executed
# Inside else

# %%
x = 5
for i in range(x):
    print(x)
    print("for loop executed")
# Out:
# 5
# for loop executed
# 5
# for loop executed
# 5
# for loop executed
# 5
# for loop executed
# 5
# for loop executed

# %%
list = [0, 1, 2, 3, 4]
for i in list:
    print(i)
    if i ==3: 
      break
else:
    print("No items in the list.")
# Out:
# 0
# 1
# 2
# 3

# %%
x =10
y =20
if x>y:
         print("if stmt executed")
