# %%
import pandas as pd
data = pd.read_csv("trainingdata.csv")
print("Training Data:\n")
print(data)
concepts = data.iloc[:, :-1].values
target = data.iloc[:, -1].values
hypothesis = concepts[0].copy()
for i in range(len(concepts)):
    if target[i] == "Yes":
        for j in range(len(hypothesis)):
            if hypothesis[j] != concepts[i][j]:
                hypothesis[j] = '?'
print("\nThe Maximum Specific Hypothesis is:")
print(hypothesis)
# Out:
# Training Data:
#
#   CGPA Interactive PracticalKnowledge CommunicationSkills LogicalThinking  \
# 0  >=9         Yes               Good                Good            Fast
# 1  >=9         Yes            Average                Good            Fast
# 2  >=8          No               Good             Average            Slow
# 3  >=9         Yes          Excellent                Good            Fast
#
#   Interest JobOffer
# 0      Yes      Yes
# 1      Yes      Yes
# 2       No       No
# 3      Yes      Yes
#
# The Maximum Specific Hypothesis is:
# ['>=9' 'Yes' '?' 'Good' 'Fast' 'Yes']

# %%
import pandas as pd
def load_dataset(modeldataset):
    data = pd.read_csv(modeldataset)
    concepts = data.iloc[:, :-1].values
    target = data.iloc[:, -1].values
    return concepts, target
def display_dataset(concepts, target):
    print("model data:\n")
    for i in range(len(concepts)):
        print(list(concepts[i]), "->", target[i])
def initialize(concepts):
    specific = concepts[0].copy()
    general = [["?" for _ in range(len(specific))]]
    return specific, general
def candidate_elimination(concepts, target):
    specific, general = initialize(concepts)
    for i, instance in enumerate(concepts):
        if target[i].lower() == "yes":
            for j in range(len(specific)):
                if specific[j] != instance[j]:
                    specific[j] = "?"
            general = [g for g in general if all(
                g[k] == "?" or g[k] == specific[k]
                for k in range(len(specific))
            )]
        else:
            new_general = []
            for j in range(len(specific)):
                if instance[j] != specific[j]:
                    hypothesis = ["?" for _ in range(len(specific))]
                    hypothesis[j] = specific[j]
                    new_general.append(hypothesis)
            general.extend(new_general)
    return specific, general
def display_result(specific, general):
    print("\nFinal Specific Hypothesis (S):")
    print(specific)
    print("\nFinal General Hypotheses (G):")
    for g in general:
        print(g)
def main():
    filename = "modeldataset.csv"
    concepts, target = load_dataset(filename)
    display_dataset(concepts, target)
    specific, general = candidate_elimination(concepts, target)
    display_result(specific, general)
if __name__ == "__main__":
    main()
# Out:
# model data:
#
# ['Sunny', 'Warm', 'Normal', 'Strong', 'Warm', 'Same'] -> Yes
# ['Sunny', 'Warm', 'High', 'Strong', 'Warm', 'Same'] -> Yes
# ['Rainy', 'Cold', 'High', 'Strong', 'Warm', 'Change'] -> No
# ['Sunny', 'Warm', 'High', 'Strong', 'Cool', 'Change'] -> Yes
#
# Final Specific Hypothesis (S):
# ['Sunny' 'Warm' '?' 'Strong' '?' '?']
#
# Final General Hypotheses (G):
# ['?', '?', '?', '?', '?', '?']
# ['Sunny', '?', '?', '?', '?', '?']
# ['?', 'Warm', '?', '?', '?', '?']
# ['?', '?', '?', '?', '?', '?']

# %%
import pandas as pd
import numpy as np
data = pd.read_csv("trainingdata.csv")
print("Training Data:\n")
print(data)
concepts = np.array(data.iloc[:, :-1])
target = np.array(data.iloc[:, -1])
S = concepts[0].copy()
G = [["?" for i in range(len(S))] for j in range(len(S))]
for i, h in enumerate(concepts):
    if target[i] == "Yes":
        for x in range(len(S)):
            if h[x] != S[x]:
                S[x] = "?"
                G[x][x] = "?"
    if target[i] == "No":
        for x in range(len(S)):
            if h[x] != S[x]:
                G[x][x] = S[x]
            else:
                G[x][x] = "?"
print("\nFinal Specific Hypothesis:")
print(S)
print("\nFinal General Hypothesis:")
for row in G:
    print(row)
# Out:
# Training Data:
#
#   CGPA Interactive PracticalKnowledge CommunicationSkills LogicalThinking  \
# 0  >=9         Yes               Good                Good            Fast
# 1  >=9         Yes            Average                Good            Fast
# 2  >=8          No               Good             Average            Slow
# 3  >=9         Yes          Excellent                Good            Fast
#
#   Interest JobOffer
# 0      Yes      Yes
# 1      Yes      Yes
# 2       No       No
# 3      Yes      Yes
#
# Final Specific Hypothesis:
# ['>=9' 'Yes' '?' 'Good' 'Fast' 'Yes']
#
# Final General Hypothesis:
# ['>=9', '?', '?', '?', '?', '?']
# ['?', 'Yes', '?', '?', '?', '?']
# ['?', '?', '?', '?', '?', '?']
# ['?', '?', '?', 'Good', '?', '?']
# ['?', '?', '?', '?', 'Fast', '?']
# ['?', '?', '?', '?', '?', 'Yes']
