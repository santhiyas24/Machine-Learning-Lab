# %%
from sklearn.linear_model import LogisticRegression
X = [[1], [2], [3], [4], [5], [6]]
y = [0, 0, 0, 1, 1, 1]
model = LogisticRegression()
model.fit(X, y)
prediction = model.predict([[4]])
probability = model.predict_proba([[4]])
print("Predicted class:", prediction[0])
print("Probability:", probability[0])
# Out:
# Predicted class: 1
# Probability: [0.36343707 0.63656293]

# %%
from sklearn.linear_model import Lasso
X = [[1], [2], [3], [4], [5]]
Y = [2, 4, 6, 8, 10]
model = Lasso(alpha=0.1)
model.fit(X, Y)
print("Coefficient:", model.coef_)
print("Intercept:", model.intercept_)
print("Prediction:", model.predict([[6]])[0])
# Out:
# Coefficient: [1.95]
# Intercept: 0.15000000000000036
# Prediction: 11.85

# %%
from sklearn.linear_model import Ridge
X = [[1], [2], [3], [4], [5]]
Y = [2, 4, 6, 8, 10]
model = Ridge(alpha=1.0)
model.fit(X, Y)
print("Coefficient:", model.coef_)
print("Intercept:", model.intercept_)
print("Prediction:", model.predict([[6]])[0])
# Out:
# Coefficient: [1.81818182]
# Intercept: 0.5454545454545459
# Prediction: 11.454545454545453

# %%
from sklearn.linear_model import ElasticNet
X = [[1], [2], [3], [4], [5]]
Y = [2, 4, 6, 8, 10]
model = ElasticNet(alpha=0.1,l1_ratio=0.5)
model.fit(X, Y)
print("Coefficient:", model.coef_)
print("Intercept:", model.intercept_)
print("Prediction:", model.predict([[6]])[0])
# Out:
# Coefficient: [1.92682927]
# Intercept: 0.21951219512195141
# Prediction: 11.78048780487805

# %%
from sklearn.metrics import mean_squared_error
actual=[3,5,7]
predicted=[2,5,8]
mse=mean_squared_error(actual,predicted)
print("Mean Squared Error:",mse)
# Out:
# Mean Squared Error: 0.6666666666666666

# %%
from sklearn.metrics import mean_absolute_error
actual=[3,5,7]
predicted=[2,5,8]
mae=mean_absolute_error(actual,predicted)
print("Mean Absoluite Error:",mae)
# Out:
# Mean Absoluite Error: 0.6666666666666666
